# %%
import numpy as np
import pandas as pd
import csv
# !pip install apyori
from apyori import apriori
from pprint import pprint

# %%
from google.colab import drive
drive.mount('/content/gdrive')

df = pd.read_csv('/content/gdrive/My Drive/data/GroceryStoreDataSet.csv', sep=',', header=None)
df = df[0].map(lambda x: x.split(','))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df
# Out:
# 0                  [MILK, BREAD, BISCUIT]
# 1      [BREAD, MILK, BISCUIT, CORNFLAKES]
# 2                 [BREAD, TEA, BOURNVITA]
# 3               [JAM, MAGGI, BREAD, MILK]
# 4                   [MAGGI, TEA, BISCUIT]
# 5                 [BREAD, TEA, BOURNVITA]
# 6                [MAGGI, TEA, CORNFLAKES]
# 7            [MAGGI, BREAD, TEA, BISCUIT]
# 8                [JAM, MAGGI, BREAD, TEA]
# 9                           [BREAD, MILK]
# 10    [COFFEE, COCK, BISCUIT, CORNFLAKES]
# 11    [COFFEE, COCK, BISCUIT, CORNFLAKES]
# 12             [COFFEE, SUGER, BOURNVITA]
# 13                  [BREAD, COFFEE, COCK]
# 14                [BREAD, SUGER, BISCUIT]
# 15            [COFFEE, SUGER, CORNFLAKES]
# 16              [BREAD, SUGER, BOURNVITA]
# 17                 [BREAD, COFFEE, SUGER]
# 18                 [BREAD, COFFEE, SUGER]
# 19        [TEA, MILK, COFFEE, CORNFLAKES]
# Name: 0, dtype: object

# %%
association_rules = apriori(df.values, min_support=0.001, min_confidence=1, min_length=3)  
association_results = list(association_rules)
pprint(association_results)
# Out:
# [RelationRecord(items=frozenset({'BREAD', 'JAM'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JAM'}), items_add=frozenset({'BREAD'}), confidence=1.0, lift=1.5384615384615383)]),
#  RelationRecord(items=frozenset({'COFFEE', 'COCK'}), support=0.15, ordered_statistics=[OrderedStatistic(items_base=frozenset({'COCK'}), items_add=frozenset({'COFFEE'}), confidence=1.0, lift=2.5)]),
#  RelationRecord(items=frozenset({'MAGGI', 'JAM'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JAM'}), items_add=frozenset({'MAGGI'}), confidence=1.0, lift=4.0)]),
#  RelationRecord(items=frozenset({'BISCUIT', 'CORNFLAKES', 'BREAD'}), support=0.05, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CORNFLAKES', 'BREAD'}), items_add=frozenset({'BISCUIT'}), confidence=1.0, lift=2.857142857142857)]),
# ...
